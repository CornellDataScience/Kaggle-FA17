# %%
import sys
sys.path.insert(0, '../Aaron/Filters')

import lee

# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_json("../train.json")
test = pd.read_json("../test.json")

# %%
x_band1 = np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train["band_1"]])
x_band2 = np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train["band_2"]])
X_train = np.concatenate([x_band1[:, :, :, np.newaxis]
                          , x_band2[:, :, :, np.newaxis]
                         , ((x_band1+x_band1)/2)[:, :, :, np.newaxis]], axis=-1)

# %%
x_band1.shape
# Out:
# (1604, 75, 75)

# %%
x_band1[0]
# Out:
# array([[-27.87836075, -27.15415955, -28.66861534, ..., -25.57348251,
#         -26.48867416, -30.50701332],
#        [-28.66852951, -27.8784008 , -27.50877571, ..., -26.4886322 ,
#         -28.67156219, -31.5941658 ],
#        [-28.66852951, -27.15415955, -25.86504173, ..., -27.1571064 ,
#         -27.88139343, -32.83712387],
#        ...,
#        [-29.09290504, -28.66916275, -30.50461197, ..., -30.0110054 ,
#         -25.8685379 , -26.48926544],
#        [-31.59168243, -27.87899208, -28.66920471, ..., -27.51227188,
#         -26.81707382, -27.51235771],
#        [-29.09290504, -26.81408119, -27.15479088, ..., -26.81703186,
#         -27.8819828 , -28.26812744]], dtype=float32)

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(1,figsize=(15,15))
for i in range(9):
    ax = fig.add_subplot(3,3,i+1)
    ax.imshow(lee.lee_filter(x_band1[i]))
plt.show()
print('Filtered through lee')
fig = plt.figure(1,figsize=(15,15))
for i in range(9):
    ax = fig.add_subplot(3,3,i+1)
    ax.imshow(x_band1[i])
plt.show()
print('Unfiltered')
# Out:
# Filtered through lee
# Unfiltered

# %%
for i in range(0,10):
    print(np.max(x_band1[i]))
# Out:
# -0.213149
# 12.5704
# -9.91848
# 4.79563
# -6.95604
# 3.86404
# -10.3501
# -13.9976
# 28.5789
# -5.6063

# %%
for i in range(0,10):
    print(np.max(lee.lee_filter(x_band1[i])))
# Out:
# -2.46221826598
# 12.1670758724
# -10.3975305557
# 4.73396276884
# -7.62601459026
# 3.35502806754
# -11.2060167789
# -14.6588065624
# 26.9727959633
# -6.25805199146

# %%
x_band1[0]
# Out:
# array([[-27.87836075, -27.15415955, -28.66861534, ..., -25.57348251,
#         -26.48867416, -30.50701332],
#        [-28.66852951, -27.8784008 , -27.50877571, ..., -26.4886322 ,
#         -28.67156219, -31.5941658 ],
#        [-28.66852951, -27.15415955, -25.86504173, ..., -27.1571064 ,
#         -27.88139343, -32.83712387],
#        ...,
#        [-29.09290504, -28.66916275, -30.50461197, ..., -30.0110054 ,
#         -25.8685379 , -26.48926544],
#        [-31.59168243, -27.87899208, -28.66920471, ..., -27.51227188,
#         -26.81707382, -27.51235771],
#        [-29.09290504, -26.81408119, -27.15479088, ..., -26.81703186,
#         -27.8819828 , -28.26812744]], dtype=float32)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e62094dd53ac> in <module>()
# ----> 1 x_band1lee[0]
#
# NameError: name 'x_band1lee' is not defined
