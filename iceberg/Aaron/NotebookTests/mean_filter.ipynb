# %%
import sys
sys.path.insert(0, '../Filters')

import mean

# %%
import numpy as np
import pandas as pd

# %%
train = pd.read_json("../../train.json")
test = pd.read_json("../../test.json")

# %%
x_band1 = np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train["band_1"]])
x_band2 = np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train["band_2"]])
X_train = np.concatenate([x_band1[:, :, :, np.newaxis]
                          , x_band2[:, :, :, np.newaxis]
                         , ((x_band1+x_band1)/2)[:, :, :, np.newaxis]], axis=-1)

# %%
x_band1.shape
# Out:
# (1604, 75, 75)

# %%
import matplotlib.pyplot as plt

# %%
x_band1mean = mean.mean_filter_df(x_band1)
# Out:
# 100%|██████████| 1604/1604 [00:38<00:00, 42.19it/s]

# %%
fig = plt.figure(1,figsize=(15,15))
for i in range(9):
    ax = fig.add_subplot(3,3,i+1)
    ax.imshow(x_band1mean[i])
plt.show()
print('Filtered through lee')
fig = plt.figure(1,figsize=(15,15))
for i in range(9):
    ax = fig.add_subplot(3,3,i+1)
    ax.imshow(x_band1[i])
plt.show()
print('Unfiltered')
# Out:
# Filtered through lee
# Unfiltered

# %%
x_band1mean
# Out:
# array([[[-27.87836075, -27.51626015, -27.91138744, ..., -26.03103638,
#          -26.03107834, -28.49784374],
#         [-28.27344513, -27.89486265, -27.80248785, ..., -26.2598238 ,
#          -26.80558777, -29.31535387],
#         [-28.66852951, -28.09240484, -27.10159445, ..., -26.42694235,
#          -27.54967356, -30.24606133],
#         ...,
#         [-27.47922611, -27.784235  , -29.29692793, ..., -27.56370878,
#          -27.46355724, -26.67178726],
#         [-30.34229374, -29.30818558, -28.93049288, ..., -28.64421177,
#          -27.55222225, -26.67180872],
#         [-30.34229374, -28.84441519, -27.62926722, ..., -28.24163532,
#          -27.25709009, -27.61988544]],
#
#        [[-12.24237537, -13.58134031, -14.92033434, ..., -11.52947998,
#          -11.2947278 , -13.16754007],
#         [-12.64450073, -13.57178688, -14.16176295, ..., -11.8220706 ,
#          -11.4047339 , -13.12509942],
#         [-14.14736986, -14.11262012, -13.3721993 , ..., -13.70845461,
#          -13.05662322, -13.53426385],
#         ...,
#         [-14.45016241, -15.34741616, -16.94126844, ..., -14.25515866,
#          -12.06613779, -12.13313031],
#         [-15.17569828, -15.68859196, -16.31597757, ..., -12.95823741,
#          -10.13141465, -10.28375387],
#         [-13.96998882, -14.73663759, -15.17885351, ..., -11.51532269,
#           -9.29738927,  -8.71461582]],
#
#        [[-24.60367584, -24.60369492, -24.73737144, ..., -20.99721527,
#          -21.75445938, -22.72359657],
#         [-21.93551731, -22.59612274, -23.18342257, ..., -21.0428586 ,
